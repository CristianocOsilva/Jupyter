# %%
import pandas as pd 

resultado_df=pd.read_excel("dre_magalu.xlsx")
display(resultado_df.head(28))
display(resultado_df.describe())
# Out:
#                       DRE CONSOLIDADO (em R$ milhões)         1T14  \
# 0                                       Receita Bruta  2699.068000
# 1                            Impostos e Cancelamentos  -430.201000
# 2                                     Receita Líquida  2268.867000
# 3                                         Custo Total -1648.866000
# 4                                         Lucro Bruto   620.001000
# 5                                 Despesas com Vendas  -419.904000
# 6                   Despesas Gerais e Administrativas  -102.279000
# 7                        Perda em Liquidação Duvidosa    -4.725000
# 8              Outras Receitas Operacionais, Líquidas     6.071000
# 9                            Equivalência Patrimonial    21.636000
# 10                     Total de Despesas Operacionais  -499.201000
# 11                                             EBITDA   120.800000
# 12                          Depreciação e Amortização   -27.030000
# ...

# %%
apurado_trimestral=resultado_df[['1T20','2T20','3T20',"4T20"]]
display(apurado_trimestral)
# Out:
#            1T20         2T20          3T20          4T20
# 0   6486.285000  6816.559000  10349.482000  12463.709000
# 1  -1251.536000 -1248.315000  -2041.156000  -2397.916000
# 2   5234.749000  5568.244000   8308.326000  10065.793000
# 3  -3814.276000 -4133.041000  -6129.592000  -7580.242000
# 4   1420.473000  1435.203000   2178.734000   2485.551000
# 5   -938.263000 -1116.343000  -1432.585000  -1675.427000
# 6   -194.625000  -181.996000   -240.690000   -289.488000
# 7    -30.008000   -29.068000    -25.381000    -33.662000
# 8     72.599000     8.495000      0.091000     -6.440000
# 9      2.445000    27.453000     65.900000     24.131000
# 10 -1087.852000 -1291.459000  -1632.665000  -1980.886000
# 11   332.621000   143.744000    546.069000    504.665000
# 12  -174.841000  -172.255000   -169.190000   -186.237000
# 13   157.780000   -28.511000    376.879000    318.428000
# 14   -94.411000   -94.557000   -102.702000   -118.825000
# ...

# %%
display(resultado_df.loc[1:5])
#indicadores_df=resultado_df.loc[:,"1T20","2T20"] ?? corrigir
#display(indicadores_df)
# Out:
#   DRE CONSOLIDADO (em R$ milhões)      1T14      2T14      3T14      4T14  \
# 1        Impostos e Cancelamentos  -430.201  -413.840  -411.046  -470.187
# 2                 Receita Líquida  2268.867  2342.759  2390.385  2777.374
# 3                     Custo Total -1648.866 -1709.040 -1710.851 -2018.152
# 4                     Lucro Bruto   620.001   633.719   679.534   759.222
# 5             Despesas com Vendas  -419.904  -415.836  -423.075  -487.443
#
#        1T15      2T15      3T15      4T15      1T16  ...      2T20      3T20  \
# 1  -402.202  -337.489  -348.436  -431.928  -460.138  ... -1248.315 -2041.156
# 2  2252.433  2107.301  2082.544  2535.981  2263.474  ...  5568.244  8308.326
# 3 -1638.609 -1477.769 -1468.678 -1814.574 -1579.910  ... -4133.041 -6129.592
# 4   613.824   629.532   613.866   721.407   683.564  ...  1435.203  2178.734
# 5  -421.328  -404.406  -408.922  -486.143  -426.777  ... -1116.343 -1432.585
#
# ...

# %%
#deletar linhas e colunas completamente vazias
resultado_df=resultado_df.dropna(how='all', axis=1)
#axis=[0] é linha e [1]=coluna

#deletar linhas que possuem pelo menos 1 valor vazio
resultado_df=resultado_df.dropna()
